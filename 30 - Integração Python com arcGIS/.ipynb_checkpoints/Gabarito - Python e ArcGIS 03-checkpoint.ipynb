# %% [markdown]
# # Usando seu login e usuário no ArcGIS
#
# Link de Referência: https://developers.arcgis.com/python/guide/working-with-different-authentication-schemes/
#
# Funcionamento:

# %% [raw]
# gis = GIS('link', 'usuario', 'senha')

# %%
from arcgis.gis import GIS

print("ArcGIS Online Org account")    
gis = GIS("https://www.arcgis.com", "thiarly.cavalcante", "@Security0")
print("Logged in as " + str(gis.properties.user.username))
# Out:
# ArcGIS Online Org account
# ---------------------------------------------------------------------------
# ArcGISLoginError                          Traceback (most recent call last)
# File ~/Desktop/PROJECTS/Impressionador-Python-Course/30 - Integração Python com arcGIS/venv/lib/python3.9/site-packages/arcgis/auth/_auth/_token.py:802, in EsriBuiltInAuth.token(self)
#     801 if self._response_type == "token":
# --> 802     self._init_response_type_token()
#     803 else:
#
# File ~/Desktop/PROJECTS/Impressionador-Python-Course/30 - Integração Python com arcGIS/venv/lib/python3.9/site-packages/arcgis/auth/_auth/_token.py:571, in EsriBuiltInAuth._init_response_type_token(self)
#     570 if response.text.find("OAUTH_0015") > -1:
# --> 571     raise ArcGISLoginError()
#     572 callback_url = response.headers["location"]
#
# ArcGISLoginError: Invalid username or password.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
webmap = gis.content.get('41281c51f9de45edaf1c8ed44bb10e30')
webmap
# Out:
# <Item title:"LA Parks and Trails Map (styled with popups)" type:Web Map owner:esri_devlabs>

# %%
from arcgis.mapping import WebMap
la_parks_trails = WebMap(webmap)
la_parks_trails
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-96cec1dc-5c9c-49fd-9298-852f3108a4a7"><img src=""></img></div>
