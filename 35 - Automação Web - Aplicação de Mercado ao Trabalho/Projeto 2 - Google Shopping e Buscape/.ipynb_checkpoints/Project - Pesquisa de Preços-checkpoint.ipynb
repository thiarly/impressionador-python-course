# %% [markdown]
# # Projeto Automação Web - Busca de Preços
# ### Objetivo: treinar um projeto em que a gente tenha que usar automações web com Selenium para buscar as informações que precisamos
#
# - Já fizemos um projeto com esse objetivo no Módulo de Python e Web e em gravações de encontros ao vivo, mas não custa nada treinar mais um pouco.
#
# ### Como vai funcionar:
#
# - Imagina que você trabalha na área de compras de uma empresa e precisa fazer uma comparação de fornecedores para os seus insumos/produtos.
#
# - Nessa hora, você vai constantemente buscar nos sites desses fornecedores os produtos disponíveis e o preço, afinal, cada um deles pode fazer promoção em momentos diferentes e com valores diferentes.
#
# - Seu objetivo: Se o valor dos produtos for abaixo de um preço limite definido por você, você vai descobrir os produtos mais baratos e atualizar isso em uma planilha.
# - Em seguida, vai enviar um e-mail com a lista dos produtos abaixo do seu preço máximo de compra.
#
# - No nosso caso, vamos fazer com produtos comuns em sites como Google Shopping e Buscapé, mas a ideia é a mesma para outros sites.
#
# ### Outra opção:
#
# - APIs
#
# ### O que temos disponível?
#
# - Planilha de Produtos, com os nomes dos produtos, o preço máximo, o preço mínimo (para evitar produtos "errados" ou "baratos de mais para ser verdade" e os termos que vamos querer evitar nas nossas buscas.
#
# ### O que devemos fazer:
#
# - Procurar cada produto no Google Shopping e pegar todos os resultados que tenham preço dentro da faixa e sejam os produtos corretos
# - O mesmo para o Buscapé
# - Enviar um e-mail para o seu e-mail (no caso da empresa seria para a área de compras por exemplo) com a notificação e a tabela com os itens e preços encontrados, junto com o link de compra. (Vou usar o e-mail pythonimpressionador@gmail.com. Use um e-mail seu para fazer os testes para ver se a mensagem está chegando)

# %%
# criar um navegador
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd

# criar o navegador
nav = webdriver.Chrome()

# importar/visualizar a base de dados
tabela_produtos = pd.read_excel("buscas.xlsx")
display(tabela_produtos)
# Out:
#              Nome Termos banidos  Preço mínimo  Preço máximo
# 0  iphone 12 64gb     mini watch          3000          3500
# 1        rtx 3060     zota galax          4000          4500

# %%
nav.get("https://www.google.com/")
produto = 'iphone 12 64gb'

#Pesquisar pelo produto:
nav.find_element('xpath', '//*[@id="APjFqb"]').send_keys(produto)
nav.find_element('xpath', '//*[@id="APjFqb"]').send_keys(Keys.ENTER)


#Entrar na aba shopping:
elementos = nav.find_elements("class name", "hdtb-mitem")

for elemento in elementos:
    if "Shopping" in elemento.text: 
        elemento.click()
        break
        
#Pegar informações do produto
lista_resultados = nav.find_elements("class name", "i0X6df")

for resultado in lista_resultados:
    preco = resultado.find_element("class name", "a8Pemb").text
    nome = resultado.find_element("class name", "tAxDx").text
    link = resultado.find_element("class name", "shntl").get_attribute('href')
    print(preco, nome, link)

# #Pesquisar os preços
# precos = nav.find_elements("class name", "a8Pemb")
# for preco in precos:
#     print(preco.text)
        
# # pesquisar o nome do produto no google


# nav.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(produto)
# nav.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
    
# # clicar na aba shopping
# elementos = nav.find_elements(By.CLASS_NAME, 'hdtb-mitem')
# for item in elementos:
#     if "Shopping" in item.text:
#         item.click()
#         break
# Out:
#   None
# R$ 3.286,05 Vitrine: iPhone 12 Apple 64GB Preto Tela 6,1 Câmera Traseira Dupla 12MP Ios None
# R$ 3.286,05 Vitrine: iPhone 12 Apple 64GB Azul Tela 6,1 Câmera Traseira Dupla 12MP None
# R$ 3.059,10 iPhone 12 64GB - Roxo - Estou Zerado None
# R$ 3.275,09 Vitrine Apple iPhone 12 64gb - Pagamento Boleto None
# R$ 3.059,10 iPhone 12 64GB - Azul - Estou Zerado None
# R$ 4.389,00 Apple iPhone 13 128GB Meia-noite Tela 6,1” 12MP None
# R$ 2.727,65 Usado: iPhone 12 64GB Preto Bom - Trocafone None
# R$ 4.716,32 iPhone 12 Apple (64GB) Azul, Tela De 6,1, 5G E Câmera Dupla De 12 Mp None
# R$ 3.470,00 iPhone 11 Apple (64GB) Preto, Tela De 6,1", 4G E Câmera De 12 Mp None
# R$ 3.049,10 Apple iPhone 12 Pro 128 GB Grafite None
# R$ 5.129,10 iPhone 12 Mini 64GB - Roxo None
# R$ 5.795,90 Iphone 12 64Gb Tela 6.1 Sem Carregador E Fone Apple None
# R$ 2.217,49 iPhone Xr 64GB Preto, Com Tela De 6,1, 4G E Câmera De 12 Mp - Mh6m3br/a None
# R$ 2.999,00 iPhone 12 - Seminovo None
# R$ 3.465,00 Iphone 12 - 64gb | Celular Apple | Usado None
# R$ 4.049,10 iPhone 12 Apple 64GB Preto Tela 6,1 12MP - iOS + Microsoft 365 Persona None
# R$ 3.577,65 Usado: iPhone 12 64GB Azul Excelente - Trocafone None
# R$ 2.850,00 Iphone 12 64gb Vitrine Swap + Cabo e Fonte None
# R$ 4.150,00 iPhone 12 128GB Lacrado 1 Ano De Garantia Preto None
# R$ 3.351,99 Apple Smartphone iPhone 12 4gb/128gb 6.1 Dual Sim Azul None
# R$ 11.049,15 iPhone 12 Pro Max 512 GB - Grafite Apple None
# R$ 4.299,90 Vitrine Seminovo Apple iPhone 12 128 GB None
# R$ 3.999,99 Smartphone iPhone 12 64GB Preto - Bom None
# R$ 4.215,00 Iphone 12 64gb | Celular Apple | Usado None
# R$ 4.939,05 iPhone 12 mini 64GB - Verde - Apple None
# R$ 4.429,00 iPhone 12 64GB Azul + brinde None
# R$ 8.499,15 iPhone 12 Pro 256 GB - Prateado Apple None
# R$ 4.799,00 iPhone 12 128gb Branco None
# R$ 5.129,05 iPhone 12 Apple 128GB Tela de 6.1 Polegadas Câmera 12MP iOS None
# R$ 4.149,00 iPhone 12 - Novo / Verde / 64 GB None
# R$ 4.049,10 Iphone 12 Apple 64gb Preto Tela 6,1” 12mp None
# R$ 3.149,00 Usado: iPhone 12 Mini 64GB Preto Muito Bom - Trocafone None
# R$ 3.399,00 Iphone 12 Apple, Tela De 6,1”, Câmera Dupla 12mp (Somente O Aparelho) (Roxo, 64 GB) None
# R$ 3.990,00 Iphone 12 (128Gb) None
# R$ 2.499,00 iPhone 12 Mini - Seminovo None
# R$ 4.429,00 iPhone 12 64GB Branco + brinde None
# R$ 100,00 Apple - Caixa de Iphone Usada - Iphone 12 Mini Branco 64gb None
# R$ 3.799,99 Vitrine Iphone 12 Preto 64Gb None
# R$ 5.604,05 iPhone 12 mini 64GB - Roxo - Apple None
# R$ 4.759,00 Celular Apple iPhone 12 128GB None
# R$ 3.499,00 Apple iPhone 12 64gb 5g Vitrine Original Bateria 100% Nf None
# R$ 4.173,00 Iphone 12 Lilás 64gb Vitrine | Celular Apple | Usado None
# R$ 3.144,15 (Seminovo) iPhone 12 Apple Preto, 64GB None
# R$ 4.167,54 Apple Iphone 12 Desbloqueado de Fabrica - Lacrado None
# R$ 3.869,10 Iphone 12 Apple 64gb Preto Tela 6,1” 12mp Ios None
# R$ 5.743,33 iPhone 13 256GB 6,1 Polegadas Câmera Dupla 12MP Apple None
# R$ 4.249,00 iPhone 12 64GB Vermelho + brinde None
# R$ 4.299,00 iPhone 12 PRO 256gb Azul Impecável None
# R$ 8.958,95 Smartphone Apple iPhone 12 64GB Câmera Dupla Preto None
# R$ 4.173,00 Iphone 12 Verde 64gb Vitrine | Celular Apple | Usado None
# R$ 3.199,00 iPhone 12 128GB azul MGJ83B/A - Seminovo None
# R$ 3.847,40 iPhone 12 64GB Branco Apple Tela Super Retina XDR 6.1” Cam. Dupla 12MP Chip A14 ... None
# R$ 3.999,00 Apple iPhone 12 mini 64GB/128GB de Armazenamento 4GB RAM Verde / 64GB None
# R$ 3.349,00 Usado: iPhone 12 Mini 64GB Preto Excelente - Trocafone None
# R$ 4.399,99 Iphone 12 64gb branco - Vitrine None
# R$ 100,00 Apple - Caixa de Iphone Usada - Iphone 12 Mini Preto 64gb None
# R$ 4.429,00 iPhone 12 64GB Lilás + brinde None
# R$ 4.099,99 Smartphone Iphone 12 64gb, Câmera de 12Mp, Rede 5G, Vermelho - Apple None
# R$ 4.190,00 IPhone 12 Apple (64GB) Azul, Tela de 6,1", 5G e Câmera Dupla de 12 MP Preto None
# R$ 4.524,00 Iphone 12 Apple (64gb) Azul, Tela De 6,1'', 5g E Câmera Dupla De 12 Mp None
