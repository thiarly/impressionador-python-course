# %% [markdown]
# ### Forma que fizemos na última aula (concatenando textos)

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo


print ('O faturamento da loja foi:' + str(faturamento) + '. '  + 'O custo da loja foi: ' + str (custo) + '. '  + 'O lucro da loja foi: ' + str (lucro) )
# Out:
# O faturamento da loja foi:2000. O custo da loja foi: 500. O lucro da loja foi: 1500

# %% [markdown]
# ### Método format

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print('O faturamento da loja foi {} e o custo foi {} sendo q o lucro foi: {} '.format(faturamento, custo, lucro))
# Out:
# O faturamento da loja foi 2000 e o custo foi 500 sendo q o lucro foi: 1500
