# %% [markdown]
# ### 1- Imposto a pagar no Lucro Presumido
#
# - 5% sobre faturamento de ISS (mensal)
# - 0,65% de PIS sobre faturamento, (mensal)
# - 3% de COFINS sobre faturmaneto, (mensal)
# - 4.8% de IR (trimestral)
# - 10% de IR Adicional sobre o que ultrapassar 20mil do faturamento (trimestral)
# - CSLL: 2,88% sobre faturamento (trimestral)

# %%
faturamento = {
    'jan': 'R$ 95.141,98',
    'fev': 'R$ 95.425,16',
    'mar': 'R$ 89.716,31',
    'abr': 'R$ 78.459,99',
    'mai': 'R$ 71.087,28',
    'jun': 'R$ 83.911,06',
    'jul': 'R$ 56.467,26',
    'ago': 'R$ 88.513,58',
    'set': 'R$ 66.552,49',
    'out': 'R$ 80.164,07',
    'nov': 'R$ 66.964,33',
    'dez': 'R$ 71.525,25',
}


# percorrer cada item (mês) do dicionario
# para cada mês eu vou:
    # vou transformar o valor em número
    # calcular o imposto mensal
    # calcular o imposto trimestral
    # construir o resultado

#  for mes in faturamento:
#     valor = faturamento[mes].replace("R$ ", "")
#     valor = valor.replace(".", "")
#     valor = valor.replace(",", ".")
#     valor = float(valor)
#     return valor


##############################################################
def transformar_numero(valor):
    valor = faturamento[mes].replace("R$ ", "")
    valor = valor.replace(".", "")
    valor = valor.replace(",", ".")
    valor = float(valor)
    return valor

def calcular_imposto_mensal(valor):
    iss = 0.05 * valor
    pis = 0.0065 * valor
    cofins = 0.03 * valor
    imposto_mensal = iss + pis + cofins
    return imposto_mensal
    
    return imposto_mensal


def calcular_imposto_trimestral(valor):
    ir = 0.048 * valor
    csll = 0.0288
    
    if valor > 20000:
        ir_adicional = (valor - 20000) * 0.1
    else:
        ir_adicional = 0
    
    imposto_trimestral = ir + csll + ir_adicional
    return imposto_trimestral
###############################################################
    

for mes in faturamento:
    
    valor = transformar_numero(faturamento[mes])
    
    imposto_mensal = calcular_imposto_mensal(valor)
    
    imposto_trimestral = calcular_imposto_trimestral(valor)
    
    
    faturamento[mes] = (f'R$ {valor:.2f}, R$ {imposto_mensal:.2f}, R$ {imposto_trimestral:.2f}')
    
print(faturamento)

    

    
    
# você precisa inserir no sistema um dicionário no formato:

# resultado = {
#     'mes': (faturamento, imposto_mensal, imposto_trimestral),
# }
# Out:
# {'jan': 'R$ 95141.98, R$ 8229.78, R$ 12081.04', 'fev': 'R$ 95425.16, R$ 8254.28, R$ 12122.95', 'mar': 'R$ 89716.31, R$ 7760.46, R$ 11278.04', 'abr': 'R$ 78459.99, R$ 6786.79, R$ 9612.11', 'mai': 'R$ 71087.28, R$ 6149.05, R$ 8520.95', 'jun': 'R$ 83911.06, R$ 7258.31, R$ 10418.87', 'jul': 'R$ 56467.26, R$ 4884.42, R$ 6357.18', 'ago': 'R$ 88513.58, R$ 7656.42, R$ 11100.04', 'set': 'R$ 66552.49, R$ 5756.79, R$ 7849.80', 'out': 'R$ 80164.07, R$ 6934.19, R$ 9864.31', 'nov': 'R$ 66964.33, R$ 5792.41, R$ 7910.75', 'dez': 'R$ 71525.25, R$ 6186.93, R$ 8585.77'}

# %% [markdown]
# ### 2 - Puxando informações de um banco de Dados

# %%
# puxando informações SQL de um banco de dados
informacoes = [(1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0.0, 400184.25, None, 567595.43, 567595.43, 2011, '', 'San Francisco', ''), (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, None, 538909.28, 538909.28, 2011, '', 'San Francisco', ''), (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, None, 335279.91, 335279.91, 2011, '', 'San Francisco', ''), (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 56120.71, 198306.9, None, 332343.61, 332343.61, 2011, '', 'San Francisco', ''), (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737.0, 182234.59, None, 326373.19, 326373.19, 2011, '', 'San Francisco', ''), (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 8601.0, 189082.74, None, 316285.74, 316285.74, 2011, '', 'San Francisco', ''), (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, None, 315981.05, 315981.05, 2011, '', 'San Francisco', ''), (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0.0, 51322.5, None, 307899.46, 307899.46, 2011, '', 'San Francisco', ''), (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, None, 303427.55, 303427.55, 2011, '', 'San Francisco', ''), (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 0.0, 17115.73, None, 302377.73, 302377.73, 2011, '', 'San Francisco', '')]
descricao = (('Id', "<class 'int'>", None, 10, 10, 0, True), ('EmployeeName', "<class 'str'>", None, 65536, 65536, 0, True), ('JobTitle', "<class 'str'>", None, 65536, 65536, 0, True), ('BasePay', "<class 'float'>", None, 54, 54, 0, True), ('OvertimePay', "<class 'float'>", None, 54, 54, 0, True), ('OtherPay', "<class 'float'>", None, 54, 54, 0, True), ('Benefits', "<class 'float'>", None, 54, 54, 0, True), ('TotalPay', "<class 'float'>", None, 54, 54, 0, True), ('TotalPayBenefits', "<class 'float'>", None, 54, 54, 0, True), ('Year', "<class 'int'>", None, 10, 10, 0, True), ('Notes', "<class 'str'>", None, 65536, 65536, 0, True), ('Agency', "<class 'str'>", None, 65536, 65536, 0, True), ('Status', "<class 'str'>", None, 65536, 65536, 0, True))

# precisamos 1º de uma lista com o nome das colunas para poder organizar as colunas da nossa tabela:
# o nome das colunas está na variável descrição, dê uma olhada.

# colunas = []
# for tupla in descricao:
#     colunas.append(tupla[0])

colunas = [tupla[0] for tupla in descricao]



import pandas as pd

tabela = pd.DataFrame.from_records(informacoes)

# para acertar nossa tabela, vamos precisar fazer:

tabela = pd.DataFrame.from_records(informacoes, columns=colunas) # onde colunas é uma lista com o nome das colunas
display(tabela)


# além disso, precisamos enviar por e-mail para o RH uma lista com o nome e o cargo de cada pessoa da tabela 
# então você precisa construir o texto do corpo desse email do tipo:

# nomes = [tupla[1] for tupla in informacoes]
# cargos = [tupla[2] for tupla in informacoes]
# print(nomes)
# print(cargos)

texto = 'RH, segue a lista de funcionários:'


for tupla in informacoes:
    nome = tupla[1]
    cargo = tupla[2]
    texto = texto + f"\n{nome}, Cargo: {cargo}"
    #print('Cargo: {}'.format(cargo))
print(texto)

# texto = """
# RH, segue a lista dos funcionários:
# Fulano, Cargo: tal
# Beltrano, Cargo: isso
# """
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25     None  567595.43         567595.43
# 1  155966.02    245131.88  137811.38     None  538909.28         538909.28
# 2  212739.13    106088.18   16452.60     None  335279.91         335279.91
# 3   77916.00     56120.71  198306.90     None  332343.61         332343.61
# 4  134401.60      9737.00  182234.59     None  326373.19         326373.19
# 5  118602.00      8601.00  189082.74     None  316285.74         316285.74
# 6   92492.01     89062.90  134426.14     None  315981.05         315981.05
# 7  256576.96         0.00   51322.50     None  307899.46         307899.46
# 8  176932.64     86362.68   40132.23     None  303427.55         303427.55
# 9  285262.00         0.00   17115.73     None  302377.73         302377.73
#
#    Year Notes         Agency Status
# 0  2011        San Francisco
# 1  2011        San Francisco
# 2  2011        San Francisco
# 3  2011        San Francisco
# 4  2011        San Francisco
# 5  2011        San Francisco
# 6  2011        San Francisco
# 7  2011        San Francisco
# 8  2011        San Francisco
# 9  2011        San Francisco
# RH, segue a lista de funcionários:
# NATHANIEL FORD, Cargo: GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# GARY JIMENEZ, Cargo: CAPTAIN III (POLICE DEPARTMENT)
# ALBERT PARDINI, Cargo: CAPTAIN III (POLICE DEPARTMENT)
# CHRISTOPHER CHONG, Cargo: WIRE ROPE CABLE MAINTENANCE MECHANIC
# PATRICK GARDNER, Cargo: DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# DAVID SULLIVAN, Cargo: ASSISTANT DEPUTY CHIEF II
# ALSON LEE, Cargo: BATTALION CHIEF, (FIRE DEPARTMENT)
# DAVID KUSHNER, Cargo: DEPUTY DIRECTOR OF INVESTMENTS
# MICHAEL MORRIS, Cargo: BATTALION CHIEF, (FIRE DEPARTMENT)
# JOANNE HAYES-WHITE, Cargo: CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)

# %% [markdown]
# ### 3 - Extração dos links de Download de Vídeos do Vimeo
#
# - Precisamos pegar os links em 1080p, 720p e 540p para importar os vídeos para uma nova plataforma

# %%
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo

lista_informacoes = (dicionario_vimeo["data"])

videos = []

for dicionario_video in lista_informacoes:
    uri = dicionario_video["uri"]
    nome = dicionario_video["name"]
    duracao = dicionario_video["duration"]
    informacoes_download = dicionario_video["download"]
    
    link540p = "" 
    link720p = ""
    link1080p = ""
        
    for dicionario_download in informacoes_download:
        
        if dicionario_download["rendition"] == "540p":
            link540p = dicionario_download["link"] 
        elif dicionario_download["rendition"] == "720p":
            link720p = dicionario_download["link"]
        elif dicionario_download["rendition"] == "1080p":
            link1080p = dicionario_download["link"]
            
    videos.append({
        
        "uri": uri,
        "nome": nome,
        "duracao": duracao,
        "link540p": link540p,
        "link720p": link720p,
        "link1080p": link1080p
    })
  
    
#print(videos[0])

tabela_videos = pd.DataFrame(videos)
display(tabela_videos)

    
    
#     for chave in dicionario_video:
#         print(chave)


# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
# Out:
#                  uri      nome  duracao  \
# 0  /videos/210375279  Aula 2.3      160
# 1  /videos/210374410  Aula 2.2      122
# 2  /videos/210373284  Aula 2.1      186
# 3  /videos/210365639  Aula 3.4      200
# 4  /videos/210364466  Aula 1.6      147
# 5  /videos/210349630  Aula 1.5      103
# 6  /videos/210348003  Aula 1.4      163
# 7  /videos/210346986  Aula 1.3       88
# 8  /videos/210345205  Aula 1.2      165
# 9  /videos/210341989  Aula 1.1      133
#
#                                             link540p  \
# 0  https://player.vimeo.com/progressive_redirect/...
# 1  https://player.vimeo.com/progressive_redirect/...
# 2  https://player.vimeo.com/progressive_redirect/...
# 3  https://player.vimeo.com/progressive_redirect/...
# 4  https://player.vimeo.com/progressive_redirect/...
# 5  https://player.vimeo.com/progressive_redirect/...
# 6  https://player.vimeo.com/progressive_redirect/...
# 7  https://player.vimeo.com/progressive_redirect/...
# 8  https://player.vimeo.com/progressive_redirect/...
# 9  https://player.vimeo.com/progressive_redirect/...
#
#                                             link720p link1080p
# 0  https://player.vimeo.com/progressive_redirect/...
# 1  https://player.vimeo.com/progressive_redirect/...
# 2  https://player.vimeo.com/progressive_redirect/...
# 3  https://player.vimeo.com/progressive_redirect/...
# 4  https://player.vimeo.com/progressive_redirect/...
# 5  https://player.vimeo.com/progressive_redirect/...
# 6  https://player.vimeo.com/progressive_redirect/...
# 7  https://player.vimeo.com/progressive_redirect/...
# 8  https://player.vimeo.com/progressive_redirect/...
# 9  https://player.vimeo.com/progressive_redirect/...

# %%
#print(len(lista_informacoes))

#print(lista_informacoes[1])

#for item in lista_informacoes:
    #print (item['uri'], item)


# for item in dicionario_vimeo:
#     print(item)
# print (dicionario_vimeo["data"])

# %%
import pprint

pprint.pprint(dicionario_video)
# Out:
# {'app': {'name': 'Parallel Uploader', 'uri': '/apps/87099'},
#  'categories': [],
#  'content_rating': ['unrated'],
#  'content_rating_class': 'unrated',
#  'created_time': '2017-03-27T22:18:23+00:00',
#  'description': None,
#  'download': [{'created_time': '2017-03-27T22:31:35+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 720,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/4a773fd4/aula_1.1%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=caad8ac609cd654af234aba6004f5299f2b432e4d97a5b5d0f8999b009d0d0cb',
#                'md5': '76a27a36793ddfdc5e2e55aa850462cd',
#                'public_name': '720p',
#                'quality': 'hd',
#                'rendition': '720p',
#                'size': 11279976,
#                'size_short': '10.76MB',
#                'type': 'video/mp4',
#                'width': 1280},
#               {'created_time': '2017-03-27T22:31:35+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 360,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/628820e5/aula_1.1%20%28360p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=0958c86d5268ef49e03262996df1350a07afe09dd6ca32f5644489d947861637',
#                'md5': '5e7c55bb6f33d410d33e54b65bfa8444',
#                'public_name': '360p',
#                'quality': 'sd',
#                'rendition': '360p',
#                'size': 4695856,
#                'size_short': '4.48MB',
#                'type': 'video/mp4',
#                'width': 640},
#               {'created_time': '2017-03-27T22:31:34+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 540,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/7f4a2f6c/aula_1.1%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=c5febad8768e842fa0e49fe92281d4321fc24ccd4dc8ca07131380821f6d07f2',
#                'md5': '8aca4864e3e9b48a67a5b787777350a4',
#                'public_name': '540p',
#                'quality': 'sd',
#                'rendition': '540p',
#                'size': 8787413,
#                'size_short': '8.38MB',
#                'type': 'video/mp4',
#                'width': 960}],
#  'duration': 133,
#  'embed': {'badges': {'hdr': False,
#                       'live': {'archived': False, 'streaming': False},
#                       'staff_pick': {'best_of_the_month': False,
#                                      'best_of_the_year': False,
#                                      'normal': False,
#                                      'premiere': False},
#                       'vod': False,
#                       'weekend_challenge': False},
#            'buttons': {'embed': False,
#                        'fullscreen': False,
#                        'hd': False,
#                        'like': False,
#                        'scaling': True,
#                        'share': False,
#                        'watchlater': False},
#            'color': '00adef',
#            'end_screen': {'type': 'empty'},
#            'event_schedule': True,
#            'html': '<iframe '
#                    'src="https://player.vimeo.com/video/210341989?h=320df58df8&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=252054" '
#                    'width="1364" height="768" frameborder="0" allow="autoplay; '
#                    'fullscreen; picture-in-picture" allowfullscreen '
#                    'title="Aula 1.1"></iframe>',
#            'interactive': False,
#            'logos': {'custom': {'active': False,
#                                 'link': None,
#                                 'sticky': False,
#                                 'url': None},
#                      'vimeo': False},
#            'playbar': True,
#            'speed': True,
#            'title': {'name': 'hide', 'owner': 'hide', 'portrait': 'hide'},
#            'uri': '/presets/120509281',
#            'volume': True},
#  'files': [{'created_time': '2017-03-27T22:31:34+00:00',
#             'fps': 24,
#             'height': 540,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/rendition/540p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=9a907283f19051daa89de80d3fd412b8e5c94ef96dbe11db789bf9748c7828e0',
#             'md5': '8aca4864e3e9b48a67a5b787777350a4',
#             'public_name': '540p',
#             'quality': 'sd',
#             'rendition': '540p',
#             'size': 8787413,
#             'size_short': '8.38MB',
#             'type': 'video/mp4',
#             'width': 960},
#            {'created_time': '2017-03-27T22:31:35+00:00',
#             'fps': 24,
#             'height': 720,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/rendition/720p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=b95c53ac43f83c34ea71bcebb67541f8374a94bb27b183d99b842286b87d5704',
#             'md5': '76a27a36793ddfdc5e2e55aa850462cd',
#             'public_name': '720p',
#             'quality': 'hd',
#             'rendition': '720p',
#             'size': 11279976,
#             'size_short': '10.76MB',
#             'type': 'video/mp4',
#             'width': 1280},
#            {'created_time': '2017-03-27T22:31:35+00:00',
#             'fps': 24,
#             'height': 360,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/rendition/360p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=f2e59bb2199f0461dfc62aeb028b9acc14b434a75c4178e8e270b39a416e4060',
#             'md5': '5e7c55bb6f33d410d33e54b65bfa8444',
#             'public_name': '360p',
#             'quality': 'sd',
#             'rendition': '360p',
#             'size': 4695856,
#             'size_short': '4.48MB',
#             'type': 'video/mp4',
#             'width': 640},
#            {'created_time': '2017-03-27T22:31:34+00:00',
#             'fps': 24,
#             'link': 'https://player.vimeo.com/external/210341989.m3u8?s=e5c802e6b2be38cba806008f1565ca5b7a3a3d0a&oauth2_token_id=1656777045',
#             'md5': '8aca4864e3e9b48a67a5b787777350a4',
#             'public_name': '540p',
#             'quality': 'hls',
#             'rendition': 'adaptive',
#             'size': 8787413,
#             'size_short': '8.38MB',
#             'type': 'video/mp4'}],
#  'has_audio': True,
#  'height': 768,
#  'is_playable': True,
#  'language': None,
#  'last_user_action_event_date': '2020-09-24T17:10:40+00:00',
#  'license': None,
#  'link': 'https://vimeo.com/210341989',
#  'manage_link': '/manage/videos/210341989',
#  'metadata': {'connections': {'albums': {'options': ['GET', 'PATCH'],
#                                          'total': 0,
#                                          'uri': '/videos/210341989/albums'},
#                               'available_albums': {'options': ['GET'],
#                                                    'total': 1,
#                                                    'uri': '/videos/210341989/available_albums'},
#                               'available_channels': {'options': ['GET'],
#                                                      'total': 0,
#                                                      'uri': '/videos/210341989/available_channels'},
#                               'comments': {'options': ['GET', 'POST'],
#                                            'total': 0,
#                                            'uri': '/videos/210341989/comments'},
#                               'credits': {'options': ['GET', 'POST'],
#                                           'total': 0,
#                                           'uri': '/videos/210341989/credits'},
#                               'likes': {'options': ['GET'],
#                                         'total': 8,
#                                         'uri': '/videos/210341989/likes'},
#                               'pictures': {'options': ['GET', 'POST'],
#                                            'total': 1,
#                                            'uri': '/videos/210341989/pictures'},
#                               'recommendations': {'options': ['GET'],
#                                                   'uri': '/videos/210341989/recommendations'},
#                               'related': None,
#                               'texttracks': {'options': ['GET', 'POST'],
#                                              'total': 0,
#                                              'uri': '/videos/210341989/texttracks'}},
#               'interactions': {'can_update_privacy_to_public': {'options': ['PATCH'],
#                                                                 'uri': '/videos/210341989'},
#                                'delete': {'options': ['DELETE'],
#                                           'uri': '/videos/210341989'},
#                                'edit': {'blocked_fields': [],
#                                         'options': ['PATCH'],
#                                         'uri': '/videos/210341989'},
#                                'edit_content_rating': {'content_rating': ['language',
#                                                                           'drugs',
#                                                                           'violence',
#                                                                           'nudity',
#                                                                           'advertisement',
#                                                                           'safe',
#                                                                           'unrated'],
#                                                        'options': ['PATCH'],
#                                                        'uri': '/videos/210341989'},
#                                'edit_privacy': {'content_type': 'application/vnd.vimeo.video',
#                                                 'options': ['PATCH'],
#                                                 'properties': [{'name': 'privacy.view',
#                                                                 'options': ['anybody',
#                                                                             'nobody',
#                                                                             'password',
#                                                                             'disable',
#                                                                             'unlisted'],
#                                                                 'required': True}],
#                                                 'uri': '/videos/210341989'},
#                                'report': {'options': ['POST'],
#                                           'reason': ['pornographic',
#                                                      'harassment',
#                                                      'ripoff',
#                                                      'incorrect rating',
#                                                      'spam',
#                                                      'causes harm',
#                                                      'csam'],
#                                           'uri': '/videos/210341989/report'},
#                                'trim': {'options': ['GET', 'POST'],
#                                         'uri': '/videos/210341989/cliptrim'},
#                                'validate': {'options': ['PUT'],
#                                             'uri': '/videos/210341989/validate'},
#                                'view_team_members': {'options': ['GET'],
#                                                      'uri': '/videos/210341989/teammembers'},
#                                'watchlater': {'added': False,
#                                               'added_time': None,
#                                               'options': ['GET',
#                                                           'PUT',
#                                                           'DELETE'],
#                                               'uri': '/users/64746254/watchlater/210341989'}},
#               'is_screen_record': False,
#               'is_vimeo_create': False},
#  'modified_time': '2022-08-18T14:04:23+00:00',
#  'name': 'Aula 1.1',
#  'parent_folder': None,
#  'pictures': {'active': True,
#               'base_link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d',
#               'default_picture': False,
#               'resource_key': '334413a22fefc8ea5d2ac104b9d8292c2dea26b6',
#               'sizes': [{'height': 75,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_100x75?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_100x75&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 100},
#                         {'height': 150,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_200x150?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_200x150&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 200},
#                         {'height': 166,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_295x166?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_295x166&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 295},
#                         {'height': 360,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_640x360?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_640x360&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 640},
#                         {'height': 540,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_960x540?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_960x540&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 960},
#                         {'height': 720,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_1280x720?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_1280x720&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 1280},
#                         {'height': 1080,
#                          'link': 'https://i.vimeocdn.com/video/626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_1920x1080?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626105194-bdec847abea0b7e7a3877cbef43983773edc1c28f0ab1fa883fca33adff25946-d_1920x1080&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 1920}],
#               'type': 'custom',
#               'uri': '/videos/210341989/pictures/626105194'},
#  'play': {'dash': {'link': 'https://player.vimeo.com/play/c/210341989/dash?s=210341989_1660920593_65578b838aca7d2e9c7c180e27e5a394&context=Vimeo%5CController%5CApi%5CResources%5CUser%5CVideosController.&log_user=0&oauth2_token_id=1656777045',
#                    'link_expiration_time': '2022-08-19T14:49:53+00:00'},
#           'hls': {'link': 'https://player.vimeo.com/play/c/210341989/hls?s=210341989_1660920593_65578b838aca7d2e9c7c180e27e5a394&context=Vimeo%5CController%5CApi%5CResources%5CUser%5CVideosController.&log_user=0&oauth2_token_id=1656777045',
#                   'link_expiration_time': '2022-08-19T14:49:53+00:00'},
#           'progressive': [{'codec': 'H264',
#                            'created_time': '2017-03-27T22:31:35+00:00',
#                            'fps': 24,
#                            'height': 720,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/4a773fd4?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=577c88c4bb03cd53deb5797dbb0ef95e84c8053d3d23fbdc107c0a504da48ac0',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': '76a27a36793ddfdc5e2e55aa850462cd',
#                            'size': 11279976,
#                            'type': 'video/mp4',
#                            'width': 1280},
#                           {'codec': 'H264',
#                            'created_time': '2017-03-27T22:31:35+00:00',
#                            'fps': 24,
#                            'height': 360,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/628820e5?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=cfe212cefd2c34e1d9abf9116a9824e9d6b0ff2c7f2bef742b0e4ffe397687f5',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': '5e7c55bb6f33d410d33e54b65bfa8444',
#                            'size': 4695856,
#                            'type': 'video/mp4',
#                            'width': 640},
#                           {'codec': 'H264',
#                            'created_time': '2017-03-27T22:31:34+00:00',
#                            'fps': 24,
#                            'height': 540,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/7f4a2f6c?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=8e06fedebb8d7b1ba8cbd35c0061413a344fe2c2f95af5dad9f9df638c13ed61',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': '8aca4864e3e9b48a67a5b787777350a4',
#                            'size': 8787413,
#                            'type': 'video/mp4',
#                            'width': 960}],
#           'status': 'playable'},
#  'player_embed_url': 'https://player.vimeo.com/video/210341989?h=320df58df8',
#  'privacy': {'add': True,
#              'comments': 'anybody',
#              'download': False,
#              'embed': 'public',
#              'view': 'anybody'},
#  'rating_mod_locked': False,
#  'release_time': '2017-03-27T22:18:23+00:00',
#  'resource_key': 'e8500cbc8697987b05a3b24b62de37b9f5413330',
#  'review_page': {'active': True,
#                  'link': 'https://vimeo.com/user64746254/review/210341989/f2711fd10a'},
#  'stats': {'plays': 27885},
#  'status': 'available',
#  'tags': [],
#  'transcode': {'status': 'complete'},
#  'type': 'video',
#  'upload': {'approach': None,
#             'complete_uri': None,
#             'form': None,
#             'link': None,
#             'redirect_url': None,
#             'size': None,
#             'status': 'complete',
#             'upload_link': None},
#  'uploader': {'pictures': {'active': False,
#                            'base_link': 'https://i.vimeocdn.com/portrait/defaults-blue',
#                            'default_picture': True,
#                            'resource_key': '06cd312fcc3908e2d839aeb00ccaaf434acb0859',
#                            'sizes': [{'height': 30,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_30x30',
#                                       'width': 30},
#                                      {'height': 72,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_72x72',
#                                       'width': 72},
#                                      {'height': 75,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_75x75',
#                                       'width': 75},
#                                      {'height': 100,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_100x100',
#                                       'width': 100},
#                                      {'height': 144,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_144x144',
#                                       'width': 144},
#                                      {'height': 216,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_216x216',
#                                       'width': 216},
#                                      {'height': 288,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_288x288',
#                                       'width': 288},
#                                      {'height': 300,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_300x300',
#                                       'width': 300},
#                                      {'height': 360,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_360x360',
#                                       'width': 360}],
#                            'type': 'default',
#                            'uri': None}},
#  'uri': '/videos/210341989',
#  'user': {'account': 'pro',
#           'available_for_hire': False,
#           'bio': None,
#           'can_work_remotely': False,
#           'capabilities': {'hasEnterpriseLihp': False,
#                            'hasLiveSubscription': False,
#                            'hasSvvTimecodedComments': False},
#           'content_filter': ['language',
#                              'drugs',
#                              'violence',
#                              'nudity',
#                              'safe',
#                              'unrated'],
#           'created_time': '2017-03-27T22:17:43+00:00',
#           'gender': '',
#           'link': 'https://vimeo.com/user64746254',
#           'location': '',
#           'location_details': {'city': None,
#                                'country': None,
#                                'country_iso_code': None,
#                                'formatted_address': '',
#                                'latitude': None,
#                                'longitude': None,
#                                'neighborhood': None,
#                                'state': None,
#                                'state_iso_code': None,
#                                'sub_locality': None},
#           'metadata': {'connections': {'albums': {'options': ['GET'],
#                                                   'total': 1,
#                                                   'uri': '/users/64746254/albums'},
#                                        'appearances': {'options': ['GET'],
#                                                        'total': 0,
#                                                        'uri': '/users/64746254/appearances'},
#                                        'block': {'options': ['GET'],
#                                                  'total': 0,
#                                                  'uri': '/me/block'},
#                                        'categories': {'options': ['GET'],
#                                                       'total': 0,
#                                                       'uri': '/users/64746254/categories'},
#                                        'channels': {'options': ['GET'],
#                                                     'total': 0,
#                                                     'uri': '/users/64746254/channels'},
#                                        'feed': {'options': ['GET'],
#                                                 'uri': '/users/64746254/feed'},
#                                        'folders': {'options': ['GET', 'POST'],
#                                                    'total': 1,
#                                                    'uri': '/users/64746254/folders'},
#                                        'folders_root': {'options': ['GET'],
#                                                         'uri': '/users/64746254/folders/root'},
#                                        'followers': {'options': ['GET'],
#                                                      'total': 176,
#                                                      'uri': '/users/64746254/followers'},
#                                        'following': {'options': ['GET'],
#                                                      'total': 0,
#                                                      'uri': '/users/64746254/following'},
#                                        'groups': {'options': ['GET'],
#                                                   'total': 0,
#                                                   'uri': '/users/64746254/groups'},
#                                        'likes': {'options': ['GET'],
#                                                  'total': 0,
#                                                  'uri': '/users/64746254/likes'},
#                                        'membership': {'options': ['PATCH'],
#                                                       'uri': '/users/64746254/membership/'},
#                                        'moderated_channels': {'options': ['GET'],
#                                                               'total': 0,
#                                                               'uri': '/users/64746254/channels?filter=moderated'},
#                                        'permission_policies': {'options': ['GET'],
#                                                                'total': 8,
#                                                                'uri': '/users/64746254/permission_policies'},
#                                        'pictures': {'options': ['GET', 'POST'],
#                                                     'total': 0,
#                                                     'uri': '/users/64746254/pictures'},
#                                        'portfolios': {'options': ['GET'],
#                                                       'total': 0,
#                                                       'uri': '/users/64746254/portfolios'},
#                                        'shared': {'options': ['GET'],
#                                                   'total': 0,
#                                                   'uri': '/users/64746254/shared/videos'},
#                                        'teams': {'options': ['GET'],
#                                                  'total': 1,
#                                                  'uri': '/users/64746254/teams'},
#                                        'videos': {'options': ['GET'],
#                                                   'total': 4510,
#                                                   'uri': '/users/64746254/videos'},
#                                        'watched_videos': {'options': ['GET'],
#                                                           'total': 0,
#                                                           'uri': '/me/watched/videos'},
#                                        'watchlater': {'options': ['GET'],
#                                                       'total': 1,
#                                                       'uri': '/users/64746254/watchlater'}}},
#           'name': 'Hashtag Treinamentos',
#           'pictures': {'active': False,
#                        'base_link': 'https://i.vimeocdn.com/portrait/defaults-blue',
#                        'default_picture': True,
#                        'resource_key': '06cd312fcc3908e2d839aeb00ccaaf434acb0859',
#                        'sizes': [{'height': 30,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_30x30',
#                                   'width': 30},
#                                  {'height': 72,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_72x72',
#                                   'width': 72},
#                                  {'height': 75,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_75x75',
#                                   'width': 75},
#                                  {'height': 100,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_100x100',
#                                   'width': 100},
#                                  {'height': 144,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_144x144',
#                                   'width': 144},
#                                  {'height': 216,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_216x216',
#                                   'width': 216},
#                                  {'height': 288,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_288x288',
#                                   'width': 288},
#                                  {'height': 300,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_300x300',
#                                   'width': 300},
#                                  {'height': 360,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_360x360',
#                                   'width': 360}],
#                        'type': 'default',
#                        'uri': None},
#           'preferences': {'videos': {'privacy': {'add': True,
#                                                  'comments': 'anybody',
#                                                  'download': True,
#                                                  'embed': 'public',
#                                                  'view': 'disable'},
#                                      'rating': ['unrated']}},
#           'resource_key': 'd9abdf36f4f1e328e1d085932436ac8647a3346d',
#           'short_bio': None,
#           'skills': [],
#           'upload_quota': {'lifetime': {'free': None,
#                                         'max': None,
#                                         'unit': None,
#                                         'used': None},
#                            'periodic': {'free': 21222207576,
#                                         'max': 21474836480,
#                                         'period': 'week',
#                                         'reset_date': '2022-08-23T00:00:00-04:00',
#                                         'unit': 'video_size',
#                                         'used': 252628904},
#                            'space': {'free': 21222207576,
#                                      'max': 21474836480,
#                                      'showing': 'periodic',
#                                      'unit': 'video_size',
#                                      'used': 252628904}},
#           'uri': '/users/64746254',
#           'websites': []},
#  'width': 1364}
